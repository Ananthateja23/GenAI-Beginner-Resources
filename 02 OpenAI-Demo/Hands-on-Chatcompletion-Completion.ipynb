# %%
print("Hello")
# Out:
# Hello

# %%
import os
import openai
import pandas 
from dotenv import load_dotenv

# %%
load_dotenv()
OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")

# %%
# OPENAI_API_KEY

# %%
openai.api_key = OPENAI_API_KEY

# %%
openai.Model.list()
# Out:
# <OpenAIObject list at 0x1c17ff4cb80> JSON: {
#   "object": "list",
#   "data": [
#     {
#       "id": "gpt-4-0613",
#       "object": "model",
#       "created": 1686588896,
#       "owned_by": "openai"
#     },
#     {
#       "id": "gpt-4",
#       "object": "model",
#       "created": 1687882411,
#       "owned_by": "openai"
#     },
#     {
#       "id": "gpt-3.5-turbo",
#       "object": "model",
#       "created": 1677610602,
#       "owned_by": "openai"
#     },
#     {
#       "id": "chatgpt-image-latest",
#       "object": "model",
#       "created": 1765925279,
#       "owned_by": "system"
#     },
#     {
#       "id": "gpt-4o-mini-tts-2025-03-20",
#       "object": "model",
#       "created": 1765610731,
#       "owned_by": "system"
#     },
#     {
#       "id": "gpt-4o-mini-tts-2025-12-15",
#       "object": "model",
#       "created": 1765610837,
#       "owned_by": "system"
#     },
#     {
#       "id": "gpt-realtime-mini-2025-12-15",
#       "object": "model",
# ...

# %%
import pandas as pd
pd.DataFrame(openai.Model.list()["data"])
# Out:
#                                     id object     created         owned_by
# 0                           gpt-4-0613  model  1686588896           openai
# 1                                gpt-4  model  1687882411           openai
# 2                        gpt-3.5-turbo  model  1677610602           openai
# 3                 chatgpt-image-latest  model  1765925279           system
# 4           gpt-4o-mini-tts-2025-03-20  model  1765610731           system
# ..                                 ...    ...         ...              ...
# 106  gpt-4o-mini-transcribe-2025-03-20  model  1765610545           system
# 107                  gpt-3.5-turbo-16k  model  1683758102  openai-internal
# 108                              tts-1  model  1681940951  openai-internal
# 109                          whisper-1  model  1677532384  openai-internal
# 110             text-embedding-ada-002  model  1671217299  openai-internal
#
# [111 rows x 4 columns]

# %% [markdown]
# ## **ChatCompletion API & Completion API**
#
# - ChatCompletion takes multiple prompts, it is used for chat conversations
# - Completion takes single prompt, it is used for text completions

# %% [markdown]
# ## **ChatCompletion API**

# %%
prompt = "Hello, How are you?"

response = openai.ChatCompletion.create(
    model = "gpt-3.5-turbo",
    messages = [
        {"role": "system", "content": "You are a helpful assistant"},
        {"role": "user", "content": prompt}
    ]
)

response
# Out:
# <OpenAIObject chat.completion id=chatcmpl-CsoDrAozb41Eva80BJIq4TqSmEnuT at 0x1c17ff711c0> JSON: {
#   "id": "chatcmpl-CsoDrAozb41Eva80BJIq4TqSmEnuT",
#   "object": "chat.completion",
#   "created": 1767178803,
#   "model": "gpt-3.5-turbo-0125",
#   "choices": [
#     {
#       "index": 0,
#       "message": {
#         "role": "assistant",
#         "content": "Hello! I'm just a computer program, so I don't have feelings, but I'm here and ready to help you with whatever you need. How can I assist you today?",
#         "refusal": null,
#         "annotations": []
#       },
#       "logprobs": null,
#       "finish_reason": "stop"
#     }
#   ],
#   "usage": {
#     "prompt_tokens": 22,
#     "completion_tokens": 37,
#     "total_tokens": 59,
#     "prompt_tokens_details": {
#       "cached_tokens": 0,
#       "audio_tokens": 0
#     },
#     "completion_tokens_details": {
#       "reasoning_tokens": 0,
#       "audio_tokens": 0,
#       "accepted_prediction_tokens": 0,
# ...

# %%
print(response["choices"][0]["message"]["content"])
# Out:
# Hello! I'm just a computer program, so I don't have feelings, but I'm here and ready to help you with whatever you need. How can I assist you today?

# %%
prompt1 = "Hello, How are you?"
prompt2 = "I am 25 years old & I am a programmer"
prompt3 = "Tell me about me"
response = openai.ChatCompletion.create(
    model = "gpt-3.5-turbo",
    messages = [
        {"role": "system", "content": "You are a helpful assistant"},
        {"role": "user", "content": prompt1},
        {"role": "user", "content": prompt2},
        {"role": "user", "content": prompt3}
    ]
)
print(response["choices"][0]["message"]["content"])
# Out:
# You have told me that you are 25 years old and a programmer. If you would like me to provide more information, please feel free to share more details about yourself.

# %%
prompt = "what is python"

response = openai.ChatCompletion.create(
    model = "gpt-3.5-turbo",
    messages = [
        {"role": "system", "content": "You are a helpful assistant"},
        {"role": "user", "content": prompt}
    ],
    max_tokens = 25
)

print(response["choices"][0]["message"]["content"])
# Out:
# Python is a popular and versatile programming language known for its simplicity and readability. It can be used for a variety of purposes,

# %%
prompt = "what is python?"

response = openai.ChatCompletion.create(
    model = "gpt-3.5-turbo",
    messages = [
        {"role": "system", "content": "You are a helpful assistant"},
        {"role": "user", "content": prompt}
    ],
    temperature = 0.5
)

print(response["choices"][0]["message"]["content"])
# Out:
# Python is a high-level, interpreted programming language known for its simplicity and readability. It is widely used for web development, data analysis, artificial intelligence, scientific computing, and more. Python supports multiple programming paradigms and has a large standard library that provides tools and modules for various tasks.

# %%
prompt = "Give me the sentiment of the sentence: This movie is Amazing!"

response = openai.ChatCompletion.create(
    model = "gpt-3.5-turbo",
    messages = [
        {"role": "system", "content": "You are a helpful assistant"},
        {"role": "user", "content": prompt}
    ],
    temperature = 0.5
)

print(response["choices"][0]["message"]["content"])
# Out:
# The sentiment of the sentence "This movie is Amazing!" is positive.

# %%
prompt = "Give me Telugu translation of the sentence: This movie is Amazing!"

response = openai.ChatCompletion.create(
    model = "gpt-3.5-turbo",
    messages = [
        {"role": "system", "content": "You are a helpful assistant"},
        {"role": "user", "content": prompt}
    ],
    temperature = 0.5
)

print(response["choices"][0]["message"]["content"])
# Out:
# ఈ చిత్రం అద్భుతమైనది!

# %%
prompt = "Detect the language of the sentence: This movie is Amazing!"

response = openai.ChatCompletion.create(
    model = "gpt-3.5-turbo",
    messages = [
        {"role": "system", "content": "You are a helpful assistant"},
        {"role": "user", "content": prompt}
    ],
    temperature = 0.5
)

print(response["choices"][0]["message"]["content"])
# Out:
# The sentence "This movie is Amazing!" is in English.

# %%
prompt = "Give me a python code to add 2 numbers"

response = openai.ChatCompletion.create(
    model = "gpt-3.5-turbo",
    messages = [
        {"role": "system", "content": "You are a helpful assistant"},
        {"role": "user", "content": prompt}
    ],
    temperature = 0.5
)

print(response["choices"][0]["message"]["content"])
# Out:
# Certainly! Here is a simple Python code to add two numbers:
#
# ```python
# # Input the two numbers
# num1 = float(input("Enter first number: "))
# num2 = float(input("Enter second number: "))
#
# # Add the two numbers
# sum = num1 + num2
#
# # Display the result
# print("The sum of", num1, "and", num2, "is:", sum)
# ```
#
# You can copy and paste this code into a Python interpreter or a Python script to add two numbers.

# %% [markdown]
# ## **Completion API**

# %%
prompt = "What is python"

response = openai.Completion.create(
    model = "babbage-002",
    prompt = prompt
)

print(response)
# Out:
# {
#   "id": "cmpl-CsoZJNlrP3AJeYgDSX96Q5pf9WJMv",
#   "object": "text_completion",
#   "created": 1767180133,
#   "model": "babbage:2023-07-21-v2",
#   "choices": [
#     {
#       "text": "'s tool to view all google translate interactions in one place? 20-Jun-",
#       "index": 0,
#       "logprobs": null,
#       "finish_reason": "length"
#     }
#   ],
#   "usage": {
#     "prompt_tokens": 3,
#     "completion_tokens": 16,
#     "total_tokens": 19
#   }
# }

# %%
print(response["choices"][0]["text"])
# Out:
# 's tool to view all google translate interactions in one place? 20-Jun-
